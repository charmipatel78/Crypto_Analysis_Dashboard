# %%
import requests
import bs4
import pandas

# %% [markdown]
# <tr style="cursor:pointer"><td><div class="BasePopover_base__T5yOf popover-base"><svg viewBox="0 0 24 24" version="1.1" xmlns="http://www.w3.org/2000/svg" height="1em" width="1em" class="sc-c1554bc0-0 iSBlZT c-i" loading="lazy" decode="async" priority="low"><use href="#star"></use></svg></div></td><td style="text-align:start"><p color="text2" font-size="14" data-sensors-click="true" class="sc-71024e3e-0 jBOvmG">1</p></td><td style="text-align:start"><div display="flex" style="min-width:0;gap:8px" class="sc-4c05d6ef-0 bLqliP"><div style="flex:1;min-width:0;overflow:hidden" class="sc-4c05d6ef-0 dlQYLv"><a href="/currencies/bitcoin/" class="cmc-link"><span data-sensors-click="true" class="sc-c1554bc0-0 sc-f8219edf-0 iSUEMj dTHQrS coin-item" style="width:100%;min-width:200px"><img class="coin-logo" src="https://s2.coinmarketcap.com/static/img/coins/64x64/1.gif" loading="lazy" decoding="async" fetchpriority="low" alt="BTC logo"><div class="sc-c1554bc0-0 sc-f8219edf-1 iSUEMj kbgNYP"><div class="sc-c1554bc0-0 sc-f8219edf-2 iSUEMj LLExB  hide-ranking-number"><p class="sc-c1554bc0-0 eWrlhi coin-item-name">Bitcoin</p><div data-nosnippet="true" class="sc-f8219edf-3 dcoDXZ"><p class="sc-c1554bc0-0 gOVMPU coin-item-symbol">BTC</p></div></div></div></span></a></div><div class="sc-4c05d6ef-0 jHuabS" style="flex-shrink: 0;"><div style="display: contents;"><div class="BasePopover_base__T5yOf popover-base"><a class="sc-c1554bc0-0 lpgBvg BaseButton_base__34gwo bt-base BaseButton_t-default__8BIzz BaseButton_size-sm__oHKNE BaseButton_v-secondary__0ChW8 BaseButton_vd__gUkWt" href="https://binance.onelink.me/y874/d585cjmx" rel="noopener nofollow noreferrer" target="_blank"><div data-role="btn-content" class="sc-c1554bc0-0 euPtyP BaseButton_btnContentWrapper__vm2Ue" style=""><div data-role="btn-content-item" class="sc-c1554bc0-0 iSUEMj BaseButton_labelWrapper___Wzzw">Buy</div></div><div class="sc-c1554bc0-0 iSUEMj BaseButton_loadingIndicatorWrapper__H2_qY" style=""><div class="sc-c1554bc0-0 iSUEMj BaseButton_loadingEl__txE0m"></div></div></a></div></div></div></div></td><td style="text-align:end"><div class="sc-631098c-0 ilZTOW rise"><span>$64,240.68</span></div></td><td style="text-align:end"><span class="sc-d5c03ba0-0 dJLZma"><span class="icon-Caret-down" style="width:12px;height:18px;display:inline-block"></span>0.10%</span></td><td style="text-align:end"><span class="sc-d5c03ba0-0 ivIsIp"><span class="icon-Caret-up" style="width:12px;height:18px;display:inline-block"></span>1.53%</span></td><td style="text-align:end"><span class="sc-d5c03ba0-0 dJLZma"><span class="icon-Caret-down" style="width:12px;height:18px;display:inline-block"></span>2.12%</span></td><td style="text-align:end"><span color="text" style="white-space:nowrap" font-size="1" data-sensors-click="true" class="sc-71024e3e-0 bbHOdE"><span><div class="BasePopover_base__T5yOf popover-base"><span>$1.28T</span></div></span></span></td><td style="text-align:end"><div class="sc-4c05d6ef-0 sc-e5e39d92-0 dlQYLv gzEKjF"><a href="/currencies/bitcoin/#markets" class="cmc-link"><span font-size="1" class="sc-71024e3e-0 bbHOdE font_weight_500" color="text" data-sensors-click="true"><div class="BasePopover_base__T5yOf popover-base"><span>$24.22B</span></div></span></a></div></td><td style="text-align:end"><div class="BasePopover_base__T5yOf popover-base"><div style="width:140px" class="sc-c594afdb-0 iMjiTG circulating-supply-cell"><div class="circulating-supply-value"><span>20.06M</span> <!-- -->BTC</div><div class="PercentageBar_wrapper___KjMj"><div class="PercentageBar_overlay-bar__Jmn3C" style="background-color:var(--c-color-gray-300);width:95.54%;z-index:0"></div></div></div></div></td><td style="text-align: right;"><div style="display: inline-block;"><div class="sc-c1554bc0-0 sc-e1464f63-0 iSUEMj jqSBRw" style="font-weight: 500;"><div class="sc-c1554bc0-0 sc-e1464f63-3 iSUEMj DSGiH md"><svg viewBox="0 0 24 24" version="1.1" xmlns="http://www.w3.org/2000/svg" height="1em" width="1em" class="sc-c1554bc0-0 euzJkK c-i" loading="lazy" decode="async" priority="low"><use href="#bull"></use></svg><span class="sc-c1554bc0-0 jLEieE sc-e1464f63-1 gjUEKa">1.21</span></div><div class="sc-c1554bc0-0 sc-e1464f63-4 iSUEMj QykbY sentiment-bar"><div class="sc-e1464f63-5 bFTybF sentiment-bar-segment"></div><div class="sc-e1464f63-5 bFTybF sentiment-bar-segment"></div><div class="sc-e1464f63-5 hFBMbe sentiment-bar-segment"></div><div class="sc-e1464f63-5 hWMwbD sentiment-bar-segment"></div><div class="sc-e1464f63-5 jBDUst sentiment-bar-segment"></div></div></div></div></td><td style="text-align: end;"><img src="https://s3.coinmarketcap.com/generated/sparklines/web/7d/2781/1.svg" alt="bitcoin-7d-price-graph" class="sc-5ed7eb1b-0 hklBFO" loading="lazy" style="width: 80px;"></td></tr>

# %% [markdown]
# <p class="sc-c1554bc0-0 eWrlhi coin-item-name">Ethereum</p>
# sc-c1554bc0-0 eWrlhi coin-item-name

# %% [markdown]
# sc-c1554bc0-0 gOVMPU coin-item-symbol
# <p class="sc-c1554bc0-0 gOVMPU coin-item-symbol">ETH</p>

# %% [markdown]
# <span>$1.29T</span>
# <span>$228.96B</span>
# <span color="text" style="white-space:nowrap" font-size="1" data-sensors-click="true" class="sc-71024e3e-0 bbHOdE"><span><div class="BasePopover_base__T5yOf popover-base"><span>$229B</span></div></span></span>

# %% [markdown]
# <div class="sc-4c05d6ef-0 sc-e5e39d92-0 dlQYLv gzEKjF"><a href="/currencies/bitcoin/#markets" class="cmc-link"><span font-size="1" class="sc-71024e3e-0 bbHOdE font_weight_500" color="text" data-sensors-click="true"><div class="BasePopover_base__T5yOf popover-base"><span>$23.6B</span></div></span></a></div>
#
# <div class="sc-4c05d6ef-0 sc-e5e39d92-0 dlQYLv gzEKjF"><a href="/currencies/ethereum/#markets" class="cmc-link"><span font-size="1" class="sc-71024e3e-0 bbHOdE font_weight_500" color="text" data-sensors-click="true"><div class="BasePopover_base__T5yOf popover-base"><span>$10.86B</span></div></span></a></div>

# %% [markdown]
# <div class="BasePopover_base__T5yOf popover-base"><div style="width:140px" class="sc-c594afdb-0 iMjiTG circulating-supply-cell"><div class="circulating-supply-value"><span>20.06M</span> <!-- -->BTC</div><div class="PercentageBar_wrapper___KjMj"><div class="PercentageBar_overlay-bar__Jmn3C" style="background-color:var(--c-color-gray-300);width:95.54%;z-index:0"></div></div></div></div>
#
# <div class="BasePopover_base__T5yOf popover-base"><div style="width:140px" class="sc-c594afdb-0 iMjiTG circulating-supply-cell"><div class="circulating-supply-value"><span>120.68M</span> <!-- -->ETH</div></div></div>

# %%
import requests
from bs4 import BeautifulSoup

headers = {
    'User-Agent': 'Mozilla/5.0'
}

# List to collect data
crypto_data = []

page = 1  # Make sure 'page' is defined
url = f'https://coinmarketcap.com/?page={page}'
response = requests.get(url, headers=headers)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, 'html.parser')

rows = soup.find_all('tr')

records_on_page = 0

for row in rows:
    tds = row.find_all('td')
    if len(tds) > 8:
        data = {}

        # Coin Name
        name_tag = tds[2].find('p', class_='sc-c1554bc0-0 eWrlhi coin-item-name')
        data['Coin Name'] = name_tag.text.strip() if name_tag else 'N/A'

        # Symbol
        symbol_tag = tds[2].find('p', class_='sc-c1554bc0-0 gOVMPU coin-item-symbol')
        data['Symbol'] = symbol_tag.text.strip() if symbol_tag else 'N/A'

        # Price
        price_tag = tds[3].find('span')
        data['Price (USD)'] = price_tag.text.strip() if price_tag else 'N/A'

        # 1h Change
        change_tag = tds[4].find('span')
        data['1h Change (%)'] = change_tag.text.strip() if change_tag else 'N/A'

        # Market Cap
        market_cap_tag = tds[7].find('span',class_="sc-71024e3e-0 bbHOdE")
        data['Market Cap'] = market_cap_tag.text.strip() if market_cap_tag else 'N/A'

        # Volume (24h)
        volume_container = tds[8]

        volume_usd_tag = volume_container.find("a")

        if volume_usd_tag:
            volume_span = volume_usd_tag.find("span")
            if volume_span:
                data["Volume (24h) USD"] = volume_span.get_text(strip=True)
            else:
                data["Volume (24h) USD"] = "N/A"
        else:
            data["Volume (24h) USD"] = "N/A"

        # Circulating Supply
        supply_tag = tds[9].find('span')
        data['Circulating Supply'] = supply_tag.text.strip() if supply_tag else 'N/A'

        crypto_data.append(data)

# %%
crypto_data
# Out:
# [{'Coin Name': 'CoinMarketCap 20 Index DTF',
#   'Symbol': 'CMC20',
#   'Price (USD)': '$130.51',
#   '1h Change (%)': '0.03%',
#   'Market Cap': '$6.16M',
#   'Volume (24h) USD': '$1.52M',
#   'Circulating Supply': '47.24K'},
#  {'Coin Name': 'Bitcoin',
#   'Symbol': 'BTC',
#   'Price (USD)': '$64,381.26',
#   '1h Change (%)': '0.17%',
#   'Market Cap': '$1.29T',
#   'Volume (24h) USD': '$26.76B',
#   'Circulating Supply': '20.06M'},
#  {'Coin Name': 'Ethereum',
#   'Symbol': 'ETH',
#   'Price (USD)': '$1,908.06',
#   '1h Change (%)': '0.25%',
#   'Market Cap': '$229.89B',
#   'Volume (24h) USD': '$8.1B',
#   'Circulating Supply': '120.68M'},
#  {'Coin Name': 'Tether',
#   'Symbol': 'USDT',
#   'Price (USD)': '$0.9991',
#   '1h Change (%)': '0.01%',
#   'Market Cap': '$183.62B',
#   'Volume (24h) USD': '$51.6B',
#   'Circulating Supply': '183.81B'},
#  {'Coin Name': 'BNB',
#   'Symbol': 'BNB',
#   'Price (USD)': '$591.19',
#   '1h Change (%)': '0.23%',
#   'Market Cap': '$78.7B',
# ...

# %%
import pandas as pd
df = pd.DataFrame(crypto_data)
df
# Out:
#                      Coin Name Symbol Price (USD) 1h Change (%) Market Cap  \
# 0   CoinMarketCap 20 Index DTF  CMC20     $130.51         0.03%     $6.16M
# 1                      Bitcoin    BTC  $64,381.26         0.17%     $1.29T
# 2                     Ethereum    ETH   $1,908.06         0.25%   $229.89B
# 3                       Tether   USDT     $0.9991         0.01%   $183.62B
# 4                          BNB    BNB     $591.19         0.23%     $78.7B
# 5                         USDC   USDC     $0.9997         0.00%    $71.88B
# 6                          XRP    XRP       $1.08         0.14%    $67.61B
# 7                       Solana    SOL      $74.28         0.17%    $43.05B
# 8                         TRON    TRX     $0.3285         0.03%    $31.17B
# 9                  Hyperliquid   HYPE      $55.55         0.22%    $14.02B
# 10                    Dogecoin   DOGE    $0.07010         0.07%    $10.88B
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

headers = {
    'User-Agent': 'Mozilla/5.0'
}

crypto_data = []

for page in range(1, 21):
    print(f"Scraping page {page}...")

    url = f'https://coinmarketcap.com/?page={page}'
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')

    rows = soup.find_all('tr')

    records_on_page = 0

    for row in rows:
        tds = row.find_all('td')
        if len(tds) > 8:
            data = {}

            # Coin Name
            name_tag = tds[2].find('p', class_='sc-c1554bc0-0 eWrlhi coin-item-name')
            data['Coin Name'] = name_tag.text.strip() if name_tag else 'N/A'

            #symbol
            symbol_tag = tds[2].find('p', class_='sc-c1554bc0-0 gOVMPU coin-item-symbol')
            data['Symbol'] = symbol_tag.text.strip() if symbol_tag else 'N/A'

            #Price
            price_tag = tds[3].find('span')
            data['Price (USD)'] = price_tag.text.strip() if price_tag else 'N/A'

            #1h change
            change_tag = tds[4].find('span')
            data['1h Change (%)'] = change_tag.text.strip() if change_tag else 'N/A'

            #market cap
            market_cap_tag = tds[7].find('span',class_="sc-71024e3e-0 bbHOdE")
            data['Market Cap'] = market_cap_tag.text.strip() if market_cap_tag else 'N/A'

            #voiume (24h)
            volume_container = tds[8]
            
            volume_usd_tag = volume_container.find("a")
            
            if volume_usd_tag:
                volume_span = volume_usd_tag.find("span")
                if volume_span:
                    data["Volume (24h) USD"] = volume_span.get_text(strip=True)
                else:
                    data["Volume (24h) USD"] = "N/A"
            else:
                data["Volume (24h) USD"] = "N/A"

            #curculating supply
            supply_tag = tds[9].find('span')
            data['Circulating Supply'] = supply_tag.text.strip() if supply_tag else 'N/A'

            crypto_data.append(data)
            records_on_page += 1

    print(f" ✅ Records scraped on page {page}: {records_on_page}")
    time.sleep(5)
# Out:
# Scraping page 1...
#  ✅ Records scraped on page 1: 15
# Scraping page 2...
#  ✅ Records scraped on page 2: 15
# Scraping page 3...
#  ✅ Records scraped on page 3: 15
# Scraping page 4...
#  ✅ Records scraped on page 4: 15
# Scraping page 5...
#  ✅ Records scraped on page 5: 15
# Scraping page 6...
#  ✅ Records scraped on page 6: 15
# Scraping page 7...
#  ✅ Records scraped on page 7: 15
# Scraping page 8...
#  ✅ Records scraped on page 8: 15
# Scraping page 9...
#  ✅ Records scraped on page 9: 15
# Scraping page 10...
#  ✅ Records scraped on page 10: 15
# Scraping page 11...
#  ✅ Records scraped on page 11: 15
# Scraping page 12...
#  ✅ Records scraped on page 12: 15
# Scraping page 13...
#  ✅ Records scraped on page 13: 15
# Scraping page 14...
#  ✅ Records scraped on page 14: 15
# Scraping page 15...
#  ✅ Records scraped on page 15: 15
# Scraping page 16...
#  ✅ Records scraped on page 16: 15
# Scraping page 17...
#  ✅ Records scraped on page 17: 15
# Scraping page 18...
# ...

# %%
# convert to DataFrame
import pandas as pd
crypto_df = pd.DataFrame(crypto_data)

#Display first 10 records
print(crypto_df.head(10))
print(f"\n✅ Total records scraped: {len(crypto_df)}")
# Out:
#                     Coin Name Symbol Price (USD) 1h Change (%) Market Cap  \
# 0  CoinMarketCap 20 Index DTF  CMC20     $130.51         0.03%     $6.16M
# 1                     Bitcoin    BTC  $64,381.26         0.17%     $1.29T
# 2                    Ethereum    ETH   $1,908.06         0.25%   $229.89B
# 3                      Tether   USDT     $0.9991         0.01%   $183.62B
# 4                         BNB    BNB     $591.19         0.23%     $78.7B
# 5                        USDC   USDC     $0.9997         0.00%    $71.88B
# 6                         XRP    XRP       $1.08         0.14%    $67.61B
# 7                      Solana    SOL      $74.28         0.17%    $43.05B
# 8                        TRON    TRX     $0.3285         0.03%    $31.17B
# 9                 Hyperliquid   HYPE      $55.55         0.22%    $14.02B
#
#   Volume (24h) USD Circulating Supply
# 0           $1.52M             47.24K
# 1          $26.76B             20.06M
# ...

# %%
crypto_df.to_excel("Crypto_Analysis_Data.xlsx",index=False)
